# %% [markdown]
# #YOLOV8 OBJECT TRACKİNG

# %% [markdown]
# ##ORTAM HAZIRLIĞI

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_couting
# Out:
# /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_couting

# %%
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.7/78.2 GB disk)

# %% [markdown]
# #TEST/TRACKİNG

# %%
# !yolo track model=yolov8n.pt source="/content/drive/MyDrive/YOLOv8/2_obj_tracking_and_couting/test.mp4" #bytetrack.yaml
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 273MB/s]
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 4.7s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/1501) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_couting/test.mp4: 384x640 5 cars, 1 bus, 89.6ms
# video 1/1 (frame 2/1501) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_couting/test.mp4: 384x640 5 cars, 1 bus, 8.1ms
# video 1/1 (frame 3/1501) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_couting/test.mp4: 384x640 5 cars, 1 bus, 6.7ms
# ...
